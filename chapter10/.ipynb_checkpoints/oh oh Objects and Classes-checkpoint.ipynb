# %% [markdown]
# #### Objetos simples

# %%
class Cat():
    pass

# %%
class Cat:
    pass

# %%
a_cat = Cat()

# %%
another_cat = Cat()

# %% [markdown]
# #### Atributos

# %%
class Cat():
    pass

# %%
a_cat = Cat()

# %%
a_cat

# %%
another_cat = Cat()

# %%
another_cat

# %%
a_cat.age = 3

# %%
a_cat.name = 'Mr. Fuzzybuttons'

# %%
a_cat.nemesis = another_cat

# %%
a_cat.age
# Out:
# 3

# %%
a_cat.name
# Out:
# 'Mr. Fuzzybuttons'

# %%
a_cat.nemesis

# %%
a_cat.nemesis.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-86a423fa8243> in <module>
# ----> 1 a_cat.nemesis.name
#
# AttributeError: 'Cat' object has no attribute 'name'

# %%
a_cat.nemesis.name = 'Mr. Bigglesworth'

# %%
a_cat.nemesis.name
# Out:
# 'Mr. Bigglesworth'

# %% [markdown]
# #### Inicialización

# %%
class Cat:
    def __init__(self):
        pass

# %%
class Cat():
    def __init__(self, name):
        self.name = name

# %%
furball = Cat('Grumpy')

# %%
print('Our latest addition:', furball.name)
# Out:
# Our latest addition: Grumpy

# %% [markdown]
# ### HERENCIA

# %%
class Car():
    pass

# %%
class Yugo(Car):
    pass

# %%
issubclass(Yugo, Car)
# Out:
# True

# %%
give_me_a_car = Car()

# %%
give_me_a_yugo = Yugo()

# %%
class Car():
    def exclaim(self):
        print("I'm a Car!")

# %%
class Yugo(Car):
    pass

# %%
give_me_a_car = Car()

# %%
give_me_a_yugo = Yugo()

# %%
give_me_a_car.exclaim()
# Out:
# I'm a Car!

# %%
give_me_a_yugo.exclaim()
# Out:
# I'm a Car!

# %% [markdown]
# #### Anular un método

# %%
class Car():
    def exclaim(self):
        print("I'm a Car!")

# %%
class Yugo(Car):
    def exclaim(self):
        print("I'm a Yugo! Much like a Car, but more Yugo-ish.")

# %%
give_me_a_car = Car()

# %%
give_me_a_yugo = Yugo()

# %%
give_me_a_car.exclaim()
# Out:
# I'm a Car!

# %%
give_me_a_yugo.exclaim()
# Out:
# I'm a Yugo! Much like a Car, but more Yugo-ish.

# %%
class Person():
    def __init__(self, name):
        self.name = name

# %%
class MDPerson(Person):
    def __init__(self, name):
        self.name = 'Doctor ' + name

# %%
class JDPerson(Person):
    def __init__(self, name):
        self.name = name + ', Esquire'

# %%
person = Person('Fudd')

# %%
doctor = MDPerson('Fudd')

# %%
lawyer = JDPerson('Fudd')

# %%
print(person.name)
# Out:
# Fudd

# %%
print(doctor.name)
# Out:
# Doctor Fudd

# %%
print(lawyer.name)
# Out:
# Fudd, Esquire

# %% [markdown]
# #### Agregar un método

# %%
class Car:
    def exclaim(self):
        print("I'm a Car!")

# %%
class Yugo(Car):
    def exclaim(self):
        print("I'm a Yugo!, Much like a Car, but more Yugo-ish")
    def need_a_push(self):
        print("A little help here?")

# %%
give_me_a_car = Car()

# %%
give_me_a_yugo = Yugo()

# %%
give_me_a_yugo.need_a_push()
# Out:
# A little help here?

# %%
give_me_a_car.need_a_push()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-25de065dd6f4> in <module>
# ----> 1 give_me_a_car.need_a_push()
#
# AttributeError: 'Car' object has no attribute 'need_a_push'

# %% [markdown]
# #### Obtener ayuda de clases padres con super()

# %%
class Person():
    def __init__(self, name):
        self.name = name

# %%
class EmailPerson(Person):
    def __init__(self, name, email):
        super().__init__(name)
        self.email = email

# %%
bob = EmailPerson('Bob Frappels', 'bob@frapples.com')

# %%
bob.name
# Out:
# 'Bob Frappels'

# %%
bob.email
# Out:
# 'bob@frapples.com'

# %%
class EmailPerson(Person):  # frustra el uso de la herencia
    def __init__(self, name, email):
        self.name = name
        self.email = email

# %% [markdown]
# #### Herencia múltiple

# %%
class Animal:
    def says(self):
        return 'I speak!'

# %%
class Horse(Animal):
    def says(self):
        return 'Neigh!'

# %%
class Donkey(Animal):
    def says(self):
        return 'Hee-haw'

# %%
class Mule(Animal, Horse):
    pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-730392b76bf7> in <module>
# ----> 1 class Mule(Animal, Horse):
#       2     pass
#
# TypeError: Cannot create a consistent method resolution
# order (MRO) for bases Animal, Horse

# %%
class Mule(Donkey, Horse):
    pass

# %%
class Hinny(Horse, Donkey):
    pass

# %%
Mule.mro()
# Out:
# [__main__.Mule, __main__.Donkey, __main__.Horse, __main__.Animal, object]

# %%
Hinny.mro()
# Out:
# [__main__.Hinny, __main__.Horse, __main__.Donkey, __main__.Animal, object]

# %%
mule = Mule()

# %%
hinny = Hinny()

# %%
mule.says()
# Out:
# 'Hee-haw'

# %%
hinny.says()
# Out:
# 'Neigh!'
