# %% [markdown]
# ### BOLEANOS

# %%
bool(True)
# Out:
# True

# %%
bool(1)
# Out:
# True

# %%
bool(45)
# Out:
# True

# %%
bool(-45)
# Out:
# True

# %%
bool(False)
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(0.0)
# Out:
# False

# %% [markdown]
# ### ENTEROS

# %%
5
# Out:
# 5

# %%
0
# Out:
# 0

# %%
05
# Out:
#   File "<ipython-input-10-65e6e002a62d>", line 1
#     05
#      ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
123
# Out:
# 123

# %%
+123
# Out:
# 123

# %%
-12
# Out:
# -12

# %%
1,000,000
# Out:
# (1, 0, 0)

# %%
million = 1_000_000

# %%
million
# Out:
# 1000000

# %%
1_2_3
# Out:
# 123

# %%
5 + 9
# Out:
# 14

# %%
100 - 7
# Out:
# 93

# %%
4 - 10
# Out:
# -6

# %%
5 + 9 + 3
# Out:
# 17

# %%
4 + 3 - 2 - 1 + 6
# Out:
# 10

# %%
5+9      +          3
# Out:
# 17

# %%
6 * 7
# Out:
# 42

# %%
7 * 6
# Out:
# 42

# %%
6 * 7 * 2 * 3
# Out:
# 252

# %%
9 / 5
# Out:
# 1.8

# %%
9 // 5
# Out:
# 1

# %%
5 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-29-adafc2937013> in <module>
# ----> 1 5 / 0
#
# ZeroDivisionError: division by zero

# %%
a = 95

# %%
a
# Out:
# 95

# %%
a - 3
# Out:
# 92

# %%
a = a - 3

# %%
a
# Out:
# 92

# %%
a = 95

# %%
tem = a - 3

# %%
a = tem

# %%
a = 95

# %%
a -= 3

# %%
a
# Out:
# 92

# %%
a = 92
a += 8

# %%
a
# Out:
# 100

# %%
a = 100

# %%
a *= 2

# %%
a
# Out:
# 200

# %%
a = 300

# %%
a /= 4

# %%
a
# Out:
# 75.0

# %%
a = 13

# %%
a //= 4

# %%
a
# Out:
# 3

# %%
9 % 5
# Out:
# 4

# %%
divmod(9, 5)
# Out:
# (1, 4)

# %%
9 // 5
# Out:
# 1

# %%
9 % 5
# Out:
# 4

# %%
2 ** 3
# Out:
# 8

# %%
2.0 ** 3
# Out:
# 8.0

# %%
0 ** 3
# Out:
# 0

# %%
2 + 3 * 4
# Out:
# 14

# %%
2 + (3 * 4)
# Out:
# 14

# %%
-5 ** 2
# Out:
# -25

# %%
-(5 ** 2)
# Out:
# -25

# %%
(-5) ** 2
# Out:
# 25
