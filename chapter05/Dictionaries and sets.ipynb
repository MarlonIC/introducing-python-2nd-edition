# %% [markdown]
# ### DICCIONARIOS

# %%
empty_dict = {}

# %%
empty_dict
# Out:
# {}

# %%
acme_customer = {'first': 'Wile', 'middle': 'E', 'last': 'Coyote'}

# %%
acme_customer
# Out:
# {'first': 'Wile', 'middle': 'E', 'last': 'Coyote'}

# %%
acme_customer = dict(first='Wile', middle='E', last='Coyote')

# %%
acme_customer
# Out:
# {'first': 'Wile', 'middle': 'E', 'last': 'Coyote'}

# %%
x = dict(name='Elmer', def='hunter')
# Out:
#   File "<ipython-input-7-c0cf74c476f2>", line 1
#     x = dict(name='Elmer', def='hunter')
#                            ^
# SyntaxError: invalid syntax

# %%
lol = [['a', 'b'], ['c', 'd'], ['e', 'f']]

# %%
dict(lol)
# Out:
# {'a': 'b', 'c': 'd', 'e': 'f'}

# %%
tol = [('a', 'b'), ('c', 'd'), ('e', 'f')]

# %%
dict(tol)
# Out:
# {'a': 'b', 'c': 'd', 'e': 'f'}

# %%
los = ['ab', 'cd', 'ef']

# %%
dict(los)
# Out:
# {'a': 'b', 'c': 'd', 'e': 'f'}

# %%
tos = ('ab', 'cd', 'ef')

# %%
dict(tos)
# Out:
# {'a': 'b', 'c': 'd', 'e': 'f'}

# %% [markdown]
# #### Agregar o cambiar un valor con [key]

# %%
pythons = {
    'Chapman': 'Graham',
    'Cleese': 'John',
    'Idle': 'Eric',
    'Jones': 'Terry',
    'Palin': 'Michael'
}

# %%
pythons
# Out:
# {'Chapman': 'Graham',
#  'Cleese': 'John',
#  'Idle': 'Eric',
#  'Jones': 'Terry',
#  'Palin': 'Michael'}

# %%
pythons['Gilliam'] = 'Gerry'

# %%
pythons
# Out:
# {'Chapman': 'Graham',
#  'Cleese': 'John',
#  'Idle': 'Eric',
#  'Jones': 'Terry',
#  'Palin': 'Michael',
#  'Gilliam': 'Gerry'}

# %%
pythons['Gilliam'] = 'Terry'

# %%
pythons
# Out:
# {'Chapman': 'Graham',
#  'Cleese': 'John',
#  'Idle': 'Eric',
#  'Jones': 'Terry',
#  'Palin': 'Michael',
#  'Gilliam': 'Terry'}

# %%
some_pythons = {
    'Graham': 'Chapman',
    'John': 'Cleese',
    'Eric': 'Idle',
    'Terry': 'Gilliam',
    'Michael': 'Palin',
    'Terry': 'Jones',
}

# %%
some_pythons
# Out:
# {'Graham': 'Chapman',
#  'John': 'Cleese',
#  'Eric': 'Idle',
#  'Terry': 'Jones',
#  'Michael': 'Palin'}

# %% [markdown]
# #### Obtener un artículo con [key] o get

# %%
some_pythons['John']
# Out:
# 'Cleese'

# %%
some_pythons['Groucho']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-1794ac099324> in <module>
# ----> 1 some_pythons['Groucho']
#
# KeyError: 'Groucho'

# %%
'Groucho' in some_pythons
# Out:
# False

# %%
some_pythons.get('John')
# Out:
# 'Cleese'

# %%
some_pythons.get('Groucho', 'Not a Python')
# Out:
# 'Not a Python'

# %%
some_pythons.get('Groucho')  # return and None

# %% [markdown]
# #### Obtener todas las llaves con keys()
